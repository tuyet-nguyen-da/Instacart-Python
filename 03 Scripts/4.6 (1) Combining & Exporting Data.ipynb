# %% [markdown]
# # Importing libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing data set

# %%
# create path
path = r'/Users/tuyetnguyen/Desktop/Career Foundry/Achievement 4/04-2023 Instacart Basket Analysis'

# %%
# import latest products data set
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# # Task (cont.)

# %% [markdown]
# ##### 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
# import orders_products_merged data set
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ##### 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 13)

# %% [markdown]
# ##### 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %% [markdown]
# ###### Check the dataframes before combining

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# ...

# %%
df_orders_products_combined.drop(columns = ['eval_set'])
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0                    0           0   2539329        1             1
# 1                    0           0   2539329        1             1
# 2                    0           0   2539329        1             1
# 3                    0           0   2539329        1             1
# 4                    0           0   2539329        1             1
# ...                ...         ...       ...      ...           ...
# 32434484       3421081     3421081   2977660   206209            13
# 32434485       3421081     3421081   2977660   206209            13
# 32434486       3421081     3421081   2977660   206209            13
# 32434487       3421081     3421081   2977660   206209            13
# 32434488       3421081     3421081   2977660   206209            13
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                          2                  8                     NaN
# ...

# %%
df_orders_products_combined = df_orders_products_combined.drop(columns = ['eval_set'])

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   2                  8                     NaN       14084
# 2                   2                  8                     NaN       12427
# 3                   2                  8                     NaN       26088
# 4                   2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# ###### Merge 2 dataframes

# %%
# merge 2 dataframes
df_orders_products_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # merge 2 dataframes
# ----> 2 df_orders_products_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
# ...

# %%
# drop column "_merge" from df_orders_products_combined to fix the error above
# drop column 'Unnamed' from df_orders_products_combined
df_orders_products_combined = df_orders_products_combined.drop(columns = ['Unnamed: 0', '_merge'])

# %% [markdown]
# ###### 6. Confirm the results of the merge using the merge flag.

# %%
# check the output
df_orders_products_combined
# Out:
#           Unnamed: 0.1  order_id  user_id  order_number  orders_day_of_week  \
# 0                    0   2539329        1             1                   2
# 1                    0   2539329        1             1                   2
# 2                    0   2539329        1             1                   2
# 3                    0   2539329        1             1                   2
# 4                    0   2539329        1             1                   2
# ...                ...       ...      ...           ...                 ...
# 32434484       3421081   2977660   206209            13                   1
# 32434485       3421081   2977660   206209            13                   1
# 32434486       3421081   2977660   206209            13                   1
# 32434487       3421081   2977660   206209            13                   1
# 32434488       3421081   2977660   206209            13                   1
#
# ...

# %%
# merge 2 dataframes
df_orders_products_merged = df_orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
# check the output
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  Unnamed: 0 product_name  aisle_id  department_id  prices _merge
# ...

# %%
# check the output using the merge flag
df_orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_orders_products_merged.shape
# Out:
# (32404859, 16)

# %%
# drop redundant columns
df_orders_products_merged = df_orders_products_merged.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0'])

# %%
# check the output before exporting
df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
df_orders_products_merged.shape
# Out:
# (32404859, 14)

# %% [markdown]
# ##### 7. Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).

# %%
# exporting
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
