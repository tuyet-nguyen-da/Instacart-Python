# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing Data

# %%
# create a data path
path = r'/Users/tuyetnguyen/Desktop/Career Foundry/Achievement 4/04-2023 Instacart Basket Analysis'

# %%
# import 'ords_prods_merged' df
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data','orders_products_merged_new_vars.pkl'))

# %%
# check the newly created dataframe
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
# 5         Soda        77              7     9.0   both  Mid-range product
# 6         Soda        77              7     9.0   both  Mid-range product
# 7         Soda        77              7     9.0   both  Mid-range product
# 8         Soda        77              7     9.0   both  Mid-range product
# 9         Soda        77              7     9.0   both  Mid-range product
#
#      busiest_day   busiest_days busiest_period_of_day
# 0  Reularly busy  Regulary busy        Average orders
# 1  Reularly busy   Slowest days        Average orders
# 2  Reularly busy   Slowest days           Most orders
# 3     Least busy   Slowest days        Average orders
# 4     Least busy   Slowest days           Most orders
# 5  Reularly busy  Regulary busy        Average orders
# 6  Reularly busy   Busiest days           Most orders
# 7  Reularly busy   Busiest days           Most orders
# 8  Reularly busy   Busiest days           Most orders
# 9     Least busy   Slowest days        Average orders

# %%
# drop redundant columns
ords_prods_merge = ords_prods_merge.drop(columns = ['_merge','busiest_day'])

# %%
# check the output
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'price_range_loc', 'busiest_days',
#        'busiest_period_of_day'],
#       dtype='object')

# %%
ords_prods_merge.shape
# Out:
# (32404859, 16)

# %%
# create a subset called 'df' of the first one million entries
df = ords_prods_merge[:1000000]

# %%
# check the shape of your newly created subset df
df.shape
# Out:
# (1000000, 16)

# %%
# check the column names and first couple of rows
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#     busiest_days busiest_period_of_day
# 0  Regulary busy        Average orders
# 1   Slowest days        Average orders
# 2   Slowest days           Most orders
# 3   Slowest days        Average orders
# 4   Slowest days           Most orders

# %% [markdown]
# # 3. Grouping Data with pandas

# %%
# group the dataframe df by the column 'product_name'
df.groupby('product_name')

# %% [markdown]
# # 4. Aggregating Data with agg()
# Calculate the mean of the “order_number” column grouped by the “department_id” column

# %%
# 1. Split the data into groups based on “department_id.”
# 2. Apply the agg() function to each group to obtain the mean values for the “order_number” column.
df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# agg() alternative
df.groupby('department_id')['order_number'].mean()
# df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# produce multiple statistics at the same time
df.groupby('department_id').agg({'order_number':['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # 5. Aggregating Data with transform()

# %%
# create 'max_order' column that stores the maximum order number for each user
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# check the output
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
#
#    product_name  aisle_id  department_id  prices    price_range_loc  \
# 0          Soda        77              7     9.0  Mid-range product
# 1          Soda        77              7     9.0  Mid-range product
# 2          Soda        77              7     9.0  Mid-range product
# 3          Soda        77              7     9.0  Mid-range product
# 4          Soda        77              7     9.0  Mid-range product
# 5          Soda        77              7     9.0  Mid-range product
# 6          Soda        77              7     9.0  Mid-range product
# 7          Soda        77              7     9.0  Mid-range product
# 8          Soda        77              7     9.0  Mid-range product
# 9          Soda        77              7     9.0  Mid-range product
# 10         Soda        77              7     9.0  Mid-range product
# 11         Soda        77              7     9.0  Mid-range product
# 12         Soda        77              7     9.0  Mid-range product
# 13         Soda        77              7     9.0  Mid-range product
# 14         Soda        77              7     9.0  Mid-range product
#
#      busiest_days busiest_period_of_day  max_order
# 0   Regulary busy        Average orders         10
# 1    Slowest days        Average orders         10
# 2    Slowest days           Most orders         10
# 3    Slowest days        Average orders         10
# 4    Slowest days           Most orders         10
# 5   Regulary busy        Average orders         10
# 6    Busiest days           Most orders         10
# 7    Busiest days           Most orders         10
# 8    Busiest days           Most orders         10
# 9    Slowest days        Average orders         10
# 10   Busiest days           Most orders         22
# 11  Regulary busy           Most orders         22
# 12  Regulary busy           Most orders         22
# 13   Busiest days           Most orders         22
# 14   Busiest days           Most orders         22

# %% [markdown]
# # 6. Deriving Columns with loc()
#
# Create a 'loyalty' flag for customers
#
# If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
#
# If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
#
# If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# 20       31  Regular customer            17
# 21       43  Regular customer             6
# 22       43  Regular customer             9
# 23       52  Regular customer             1
# 24       52  Regular customer             2
# 25       52  Regular customer             3
# 26       52  Regular customer             5
# 27       52  Regular customer             7
# 28       52  Regular customer             9
# 29       52  Regular customer            10
# 30       52  Regular customer            11
# 31       52  Regular customer            12
# 32       52  Regular customer            15
# 33       52  Regular customer            17
# 34       52  Regular customer            18
# 35       52  Regular customer            19
# 36       52  Regular customer            21
# 37       67  Regular customer             1
# 38       67  Regular customer             2
# 39       67  Regular customer             3
# 40       67  Regular customer             4
# 41       67  Regular customer             5
# 42       67  Regular customer             6
# 43       67  Regular customer             8
# 44       67  Regular customer             9
# 45       67  Regular customer            10
# 46       67  Regular customer            11
# 47       67  Regular customer            12
# 48       67  Regular customer            13
# 49       67  Regular customer            14
# 50       67  Regular customer            16
# 51       67  Regular customer            18
# 52       67  Regular customer            19
# 53       67  Regular customer            21
# 54       67  Regular customer            22
# 55       67  Regular customer            23
# 56       81      New customer             3
# 57       81      New customer             5
# 58       82  Regular customer             1
# 59       82  Regular customer             3

# %% [markdown]
# # Task

# %% [markdown]
# ##### 1. Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %% [markdown]
# ##### 2. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# 1. Split the data into groups based on “department_id.”
# 2. Apply the agg() function to each group to obtain the mean values for the “order_number” column.
ords_prods_merge.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ##### 3. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# The entire dataframe contains all of the department IDs ranging from 1 to 21, while the subset only includes 8 department IDs.
#
# Additionally, the average number of orders differs between the entire dataframe and the subset, with no discernible pattern to the difference.

# %% [markdown]
# ##### 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %% [markdown]
# Please refer to part 5 and 6 above

# %% [markdown]
# ##### 5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# produce multiple statistics at the same time
ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# Based on the descriptive analysis provided, it appears that the average price of products purchased by loyal customers is the lowest among the three customer types.

# %% [markdown]
# ##### 6. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# ###### If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# ###### If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# create column name 'avg_price_purchased' that stores the average prices of products purchased by each user
ords_prods_merge['avg_price_purchased'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# check the output
ords_prods_merge[['user_id','prices', 'avg_price_purchased']].head(30)
# Out:
#     user_id  prices  avg_price_purchased
# 0         1     9.0             6.367797
# 1         1     9.0             6.367797
# 2         1     9.0             6.367797
# 3         1     9.0             6.367797
# 4         1     9.0             6.367797
# 5         1     9.0             6.367797
# 6         1     9.0             6.367797
# 7         1     9.0             6.367797
# 8         1     9.0             6.367797
# 9         1     9.0             6.367797
# 10       15     9.0             3.980556
# 11       15     9.0             3.980556
# 12       15     9.0             3.980556
# 13       15     9.0             3.980556
# 14       15     9.0             3.980556
# 15       19     9.0             8.372059
# 16       19     9.0             8.372059
# 17       19     9.0             8.372059
# 18       21     9.0             7.012683
# 19       31     9.0             8.137793
# 20       31     9.0             8.137793
# 21       43     9.0             7.444898
# 22       43     9.0             7.444898
# 23       52     9.0             6.356287
# 24       52     9.0             6.356287
# 25       52     9.0             6.356287
# 26       52     9.0             6.356287
# 27       52     9.0             6.356287
# 28       52     9.0             6.356287
# 29       52     9.0             6.356287

# %% [markdown]
# ###### Create a column named 'spending_flag'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price_purchased'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['avg_price_purchased'] >= 10, 'spending_flag'] = 'High spender'

# %%
# check the output
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %% [markdown]
# ##### 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# ###### If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# ###### If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# ###### If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# create a column named 'order_frequency' that stores the median of “days_since_prior_order”
ords_prods_merge['median_order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# check the output
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_order_frequency']]
# Out:
#           user_id  days_since_prior_order  median_order_frequency
# 0               1                     NaN                    20.5
# 1               1                    15.0                    20.5
# 2               1                    21.0                    20.5
# 3               1                    29.0                    20.5
# 4               1                    28.0                    20.5
# ...           ...                     ...                     ...
# 32404854   202557                     1.0                     8.0
# 32404855   202557                     3.0                     8.0
# 32404856   203436                     NaN                    15.0
# 32404857   203436                    15.0                    15.0
# 32404858   205420                     NaN                    13.0
#
# [32404859 rows x 3 columns]

# %% [markdown]
# ###### Create an order frequency flag that marks the regularity of a user’s ordering behavior

# %%
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_order_frequency'] > 10) & (ords_prods_merge['median_order_frequency'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# check the output
ords_prods_merge[['user_id', 'days_since_prior_order', 'median_order_frequency', 'order_frequency_flag']].head(30)
# Out:
#     user_id  days_since_prior_order  median_order_frequency  \
# 0         1                     NaN                    20.5
# 1         1                    15.0                    20.5
# 2         1                    21.0                    20.5
# 3         1                    29.0                    20.5
# 4         1                    28.0                    20.5
# 5         1                    19.0                    20.5
# 6         1                    20.0                    20.5
# 7         1                    14.0                    20.5
# 8         1                     0.0                    20.5
# 9         1                    30.0                    20.5
# 10       15                     7.0                    10.0
# 11       15                     8.0                    10.0
# 12       15                     7.0                    10.0
# 13       15                     7.0                    10.0
# 14       15                    14.0                    10.0
# 15       19                     6.0                     6.0
# 16       19                     8.0                     6.0
# 17       19                     6.0                     6.0
# 18       21                     6.0                     7.5
# 19       31                     7.0                     6.0
# 20       31                     8.0                     6.0
# 21       43                     4.0                    10.0
# 22       43                     3.0                    10.0
# 23       52                     NaN                     8.0
# 24       52                     7.0                     8.0
# 25       52                     7.0                     8.0
# 26       52                     8.0                     8.0
# 27       52                     8.0                     8.0
# 28       52                     7.0                     8.0
# 29       52                     8.0                     8.0
#
#      order_frequency_flag
# 0   Non-frequent customer
# 1   Non-frequent customer
# 2   Non-frequent customer
# 3   Non-frequent customer
# 4   Non-frequent customer
# 5   Non-frequent customer
# 6   Non-frequent customer
# 7   Non-frequent customer
# 8   Non-frequent customer
# 9   Non-frequent customer
# 10      Frequent customer
# 11      Frequent customer
# 12      Frequent customer
# 13      Frequent customer
# 14      Frequent customer
# 15      Frequent customer
# 16      Frequent customer
# 17      Frequent customer
# 18      Frequent customer
# 19      Frequent customer
# 20      Frequent customer
# 21      Frequent customer
# 22      Frequent customer
# 23      Frequent customer
# 24      Frequent customer
# 25      Frequent customer
# 26      Frequent customer
# 27      Frequent customer
# 28      Frequent customer
# 29      Frequent customer

# %%
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        28768417
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# ##### 8. Ensure your notebook is clean and structured and that your code is well commented.
# ##### 9. Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merge_group.pkl'))

# %% [markdown]
# ##### 10. Save your notebook and submit it to your tutor for review.

# %% [markdown]
# ##### ***Cleaning data for visualization in task 4.9

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 100, 'prices'] = np.nan

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices    price_range_loc   busiest_days  \
# 0         Soda  ...     9.0  Mid-range product  Regulary busy
# 1         Soda  ...     9.0  Mid-range product   Slowest days
# 2         Soda  ...     9.0  Mid-range product   Slowest days
# 3         Soda  ...     9.0  Mid-range product   Slowest days
# 4         Soda  ...     9.0  Mid-range product   Slowest days
#
#   busiest_period_of_day max_order  loyalty_flag  avg_price_purchased  \
# 0        Average orders        10  New customer             6.367797
# 1        Average orders        10  New customer             6.367797
# 2           Most orders        10  New customer             6.367797
# 3        Average orders        10  New customer             6.367797
# 4           Most orders        10  New customer             6.367797
#
#   spending_flag  median_order_frequency   order_frequency_flag
# 0   Low spender                    20.5  Non-frequent customer
# 1   Low spender                    20.5  Non-frequent customer
# 2   Low spender                    20.5  Non-frequent customer
# 3   Low spender                    20.5  Non-frequent customer
# 4   Low spender                    20.5  Non-frequent customer
#
# [5 rows x 22 columns]
