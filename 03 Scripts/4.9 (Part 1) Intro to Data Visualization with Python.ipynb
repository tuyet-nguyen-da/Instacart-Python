# %% [markdown]
# # 1. Importing Libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing Data

# %%
# create a path to datasets
path = r'/Users/tuyetnguyen/Desktop/Career Foundry/Achievement 4/04-2023 Instacart Basket Analysis'

# %% [markdown]
# ##### 4. Wrangle the data so that it follows consistent logic; for example, rename columns with illogical names and drop columns that don’t add anything to your analysis.

# %%
# import customer.csv
df_customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %%
# take a look at the df
df_customers.head(15)
# Out:
#     user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %% [markdown]
# Observation:
# Column names are inconsistent --> rename columns First Name, Surnam, Gender, STATE, Age

# %%
# rename Name
df_customers = df_customers.rename(columns={'First Name': 'first_name', 'Surnam': 'surname', 'Gender': 'gender', 'STATE': 'state', 'Age': 'age'})

# %%
# check the output
df_customers.head(5)
# Out:
#    user_id first_name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# ##### 5. Complete the fundamental data quality and consistency checks you’ve learned throughout this Achievement; for example, check for and address missing values and duplicates, and convert any mixed-type data.

# %%
# check the size of the df
df_customers.shape
# Out:
# (206209, 10)

# %% [markdown]
# ###### Missing values

# %%
# check missing value
df_customers.isnull().sum()
# Out:
# user_id             0
# first_name      11259
# surname             0
# gender              0
# state               0
# age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %% [markdown]
# Column 'first_name' is missing 11259 values

# %%
# create subset of the dataframe containing only the values in question
df_nan = df_customers[df_customers['first_name'].isnull()== True]

# %%
df_nan
# Out:
#         user_id first_name   surname  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         n_dependants fam_status  income
# ...

# %% [markdown]
# The analyst did not observe any significant impact of the missing values on the analysis process or results --> decided to leave the data as it is."

# %% [markdown]
# ###### Duplicates

# %%
# find duplicates
df_dups = df_customers[df_customers.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, surname, gender, state, age, date_joined, n_dependants, fam_status, income]
# Index: []

# %% [markdown]
# No duplicates found

# %% [markdown]
# ##### Mixed-type data

# %%
# check for mixed type
for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
# check data types of all columns of the dataframe
df_customers.dtypes
# Out:
# user_id          int64
# first_name      object
# surname         object
# gender          object
# state           object
# age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
df_customers['first_name'].dtype
# Out:
# dtype('O')

# %%
# convert data types of first_name, surname, state to string 
for col in ['first_name', 'surname', 'state'  ]:
    df_customers[col] = df_customers[col].astype('str')

# %%
# check the result
df_customers['first_name'].dtypes
# Out:
# dtype('O')

# %%
# convert the 'date_joined' column to date data type
df_customers['date_joined'] = pd.to_datetime(df_customers['date_joined'])

# %%
# check the result
df_customers['date_joined'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# convert 
for col in ['gender', 'fam_status']:
    df_customers[col] = df_customers[col].astype('category')

# %%
# check the result
df_customers[['gender', 'fam_status']].dtypes
# Out:
# gender        category
# fam_status    category
# dtype: object

# %%
# check data type of the entire df
df_customers.dtypes
# Out:
# user_id                  int64
# first_name              object
# surname                 object
# gender                category
# state                   object
# age                      int64
# date_joined     datetime64[ns]
# n_dependants             int64
# fam_status            category
# income                   int64
# dtype: object

# %%
# descriptive statistic
df_customers.describe()
# Out:
#              user_id            age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# ##### 6. Combine your customer data with the rest of your prepared Instacart data. (Hint: Make sure the key columns are the same data type!)

# %%
# import the prepared data:
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data','orders_products_merge_group.pkl'))

# %%
# check data type of 'user_id', key column, of the ords_prods_merge df
ords_prods_merge['user_id'].dtype
# Out:
# dtype('int64')

# %%
ords_prods_merge.shape
# Out:
# (32404859, 22)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices    price_range_loc   busiest_days  \
# ...

# %%
df_customers.shape
# Out:
# (206209, 10)

# %%
df_customers.head()
# Out:
#    user_id first_name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48  2017-01-01
# 1    33890   Patricia      Hart  Female  New Mexico   36  2017-01-01
# 2    65803    Kenneth    Farley    Male       Idaho   35  2017-01-01
# 3   125935   Michelle     Hicks  Female        Iowa   40  2017-01-01
# 4   130797        Ann   Gilmore  Female    Maryland   26  2017-01-01
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# export the cleaned data set
df_customers.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'customers_cleaned.pkl'))

# %%
# combine
orders_products_customers_merge = ords_prods_merge.merge(df_customers, on = 'user_id', indicator = True)

# %%
# check the result
orders_products_customers_merge.shape
# Out:
# (32404859, 32)

# %%
orders_products_customers_merge.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# ...

# %%
orders_products_customers_merge['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ##### 8. Export this new dataframe as a pickle file so you can continue to use it in the second part of this task.

# %%
orders_products_customers_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merge.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices    price_range_loc   busiest_days  \
# ...

# %%
orders_products_customers_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'price_range_loc', 'busiest_days',
#        'busiest_period_of_day', 'max_order', 'loyalty_flag',
#        'avg_price_purchased', 'spending_flag', 'median_order_frequency',
#        'order_frequency_flag', 'first_name', 'surname', 'gender', 'state',
#        'age', 'date_joined', 'n_dependants', 'fam_status', 'income', '_merge'],
#       dtype='object')

# %%
orders_products_customers_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  first_name  surname  gender    state age date_joined  \
# ...
